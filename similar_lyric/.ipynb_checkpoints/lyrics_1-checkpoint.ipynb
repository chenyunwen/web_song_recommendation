# %% [markdown]
# # PART1: 以 jieba 探索文本主題 (歌詞文本)

# %%
import matplotlib.pyplot as plt
import numpy as np
import jieba.analyse
import codecs
import pandas as pd
#文字雲
from wordcloud import WordCloud

# %% [markdown]
# ## 設定為繁中字典

# %%
jieba.set_dictionary("jieba_dict/dict.txt.big")

# %% [markdown]
# ## 1. 透過 tf-idf 原理，取每首歌的前10大重要的tag (共33首歌)

# %%
df = pd.read_csv('./data/merged.csv')
df = df[['Singer', 'Name', 'Lyric', 'Category']].astype(str)
df.drop(df[df.Singer == 'nan'].index, inplace=True)
df.drop(df[df.Name == 'Name'].index, inplace=True)
print("\033[32mTotal number of data: %d\033[0m" %len(df))
df
# Out:
# Total number of data: 991
#     Singer       Name                                              Lyric  \
# 0    A-Lin   One Life  白雲撞進藍天 激起昨天畫面我想起你的臉好久不見 在遠方的My Friend不論晴天雨天 也會...
# 1    A-Lin   最好的朋友在身邊  一起笑一起哭一起鬧久別的回憶又浮現一點點一天天一年年最好的朋友在身邊一起走一起跑一起跳相聚到...
# 2    A-Lin       愛的可能  你出現我身邊 像個奇蹟發生沒想到會是你 讓我如此失魂我心中的感覺是這樣陌生快樂的牽掛在相聚的...
# 3    A-Lin      太太太耐斯  孩子還沒睡 拜託別鬧手遊聲太吵 狗狗在叫碗盤在洗碗槽 主婦的煩惱惱公不瞭 他先洗澡奶瓶把香水...
# 4    A-Lin    抱歉 我不抱歉  恨 什麼叫恨 這個單字 好陌生我只記得 一路走來 愛的人就算他們 多可恨等 雖然溫柔 還打不...
# ..     ...        ...                                                ...
# 992    鄧紫棋      回憶的沙漏  拼圖一片片失落　像楓葉的冷漠牆上的鐘　默默數著寂寞咖啡飄散過香味　剩苦澀陪著我想念的心　埋葬...
# 993    鄧紫棋    多遠都要在一起  想聽你聽過的音樂 想看你看過的小說我想收集每一刻 我想看到你眼裡的世界想到你到過的地方 和你...
# 994    鄧紫棋       兩個自己  像  從不認識你像全部的回憶  都已被你拋棄無法看透你直覺你心裡有  太多的秘密被你蒙住了眼...
# 995    鄧紫棋     兩個你(粵)  像  未曾認識你像全部憶記  你早拋棄太異樣  想要望穿你直覺這刻你有  太多可揭秘這場遊戲...
# 996    鄧紫棋       後會無期  當一艘船沉入海底當一個人成了謎你不知道他們為何離去那聲再見竟是他最後一句當一輛車消失天際當一...
#
#     Category
# 0         友情
# 1         友情
# 2         友情
# 3     反抗反駁反諷
# 4     反抗反駁反諷
# ..       ...
# 992       離別
# 993       離別
# 994       離別
# 995       離別
# 996       離別
#
# [991 rows x 4 columns]

# %%
def remove_punctuation(line):
    line = str(line)
    if line.strip() == '':
        return ''
    re_han = re.compile(u"[^a-zA-Z0-9\u4E00-\u9FA5]")
    line = re_han.sub('', line)
    return line

# %%
def getTopTen(line):
    words = jieba.analyse.extract_tags(line, 10)
    return words

# %%
stopwords = [line.strip() for line in open('./data/stopwords.txt', 'r', encoding='utf-8').readlines()]
df['top_10'] = df['Lyric'].apply(getTopTen)

# %%
df
# Out:
#     Singer       Name                                              Lyric  \
# 0    A-Lin   One Life  白雲撞進藍天 激起昨天畫面我想起你的臉好久不見 在遠方的My Friend不論晴天雨天 也會...
# 1    A-Lin   最好的朋友在身邊  一起笑一起哭一起鬧久別的回憶又浮現一點點一天天一年年最好的朋友在身邊一起走一起跑一起跳相聚到...
# 2    A-Lin       愛的可能  你出現我身邊 像個奇蹟發生沒想到會是你 讓我如此失魂我心中的感覺是這樣陌生快樂的牽掛在相聚的...
# 3    A-Lin      太太太耐斯  孩子還沒睡 拜託別鬧手遊聲太吵 狗狗在叫碗盤在洗碗槽 主婦的煩惱惱公不瞭 他先洗澡奶瓶把香水...
# 4    A-Lin    抱歉 我不抱歉  恨 什麼叫恨 這個單字 好陌生我只記得 一路走來 愛的人就算他們 多可恨等 雖然溫柔 還打不...
# ..     ...        ...                                                ...
# 992    鄧紫棋      回憶的沙漏  拼圖一片片失落　像楓葉的冷漠牆上的鐘　默默數著寂寞咖啡飄散過香味　剩苦澀陪著我想念的心　埋葬...
# 993    鄧紫棋    多遠都要在一起  想聽你聽過的音樂 想看你看過的小說我想收集每一刻 我想看到你眼裡的世界想到你到過的地方 和你...
# 994    鄧紫棋       兩個自己  像  從不認識你像全部的回憶  都已被你拋棄無法看透你直覺你心裡有  太多的秘密被你蒙住了眼...
# 995    鄧紫棋     兩個你(粵)  像  未曾認識你像全部憶記  你早拋棄太異樣  想要望穿你直覺這刻你有  太多可揭秘這場遊戲...
# 996    鄧紫棋       後會無期  當一艘船沉入海底當一個人成了謎你不知道他們為何離去那聲再見竟是他最後一句當一輛車消失天際當一...
#
#     Category                                      top_10
# 0         友情  [Life, 我們, 一天, 期待, 哪邊, 邊要, 出現, 守成, 整夜, 重逢]
# 1         友情  [一起, 一天天, 永在, 鬧久, 別的, 回憶, 浮現, 一點點, 身邊, 永遠]
# 2         友情   [我會, 屬於, 不會, 記得, 孤單, 時候, 因為, 還有, 傷神, 我的門]
# 3     反抗反駁反諷  [太太, 太耐斯, 什麼, 超過, 太過, 發脾氣, 心軟, 忘我, 晚餐, 候命]
# 4     反抗反駁反諷    [抱歉, 他們, 每枝, 什麼, 雖然, 我們, 每個, 每張, 真實, 還原]
# ..       ...                                         ...
# 992       離別    [墜落, 流星, 過後, 沙漏, 燦爛, 奪去, 輪廓, 剎那, 回憶, 絢麗]
# 993       離別  [遠距離, 離開, 每一刻, 習慣, 總是, 寧願, 換個, 還能, 遙遠, 愛著]
# 994       離別    [兩個, 一個, 心裡, 自己, 我該, 離去, 還是, 繼續, 忘記, 逃離]
# 995       離別    [兩個, 一個, 這場, 遊戲, 學懂, 怎樣, 識別, 抽離, 轉機, 忘記]
# 996       離別   [一個, 人成, 他們, 為何, 離去, 知道, 竟是, 一輛車, 天際, 結局]
#
# [991 rows x 5 columns]

# %% [markdown]
# ## 2. 把所有歌的 10 大 tags 再取前 N 個tags，N 可自行決定，此處先取 N = 15 做示範 print 出
# - 文章當中是取 N = 200

# %%
all_tags = []
for tag in df['top_10']:
    all_tags.extend(tag)
all_tags_s = " ".join(all_tags)
all_tags_s
# Out:
# 'Life 我們 一天 期待 哪邊 邊要 出現 守成 整夜 重逢 一起 一天天 永在 鬧久 別的 回憶 浮現 一點點 身邊 永遠 我會 屬於 不會 記得 孤單 時候 因為 還有 傷神 我的門 太太 太耐斯 什麼 超過 太過 發脾氣 心軟 忘我 晚餐 候命 抱歉 他們 每枝 什麼 雖然 我們 每個 每張 真實 還原 YA 笑笑 還是 城門 味道 鬧鐘 吃飽 飆一飆 機會 苗條 討好 變成 其實 血脈 奔馳 愛著 防著 複雜 一個 Yeah 麻煩 over 愛我 一位 Oh 極限 具備 全職 溫柔 大排長龍 頒給 男主角 娛樂 有完沒完 好戲 最佳 看戲 愛心 只在乎 大師級 這個 變得 一點 他會 男人 愛變 珍貴 鑽石 昂貴 可憐 算了吧 也罷 不上不下 一個 還是 自顧不暇 一念之差 那就算了 何必 不如 無邊 無悔 蒼穹 羽化成仙 逍遙 風雨 千渡 萬劫 蒼茫 心魔 就讓 完美 傷心 奪眶 偽裝 沒人 咬牙 好不好 看到 做夢 我們 遙遠 風景 如詩 變遷 游離 溫暖 仍教 下個 終點 悲傷 感覺 表現 一個 討厭 依賴 回頭 每當 虧欠 遠遠 無人知曉 怎麼 風吹 心湖 陣陣 攪和 沙沙 欲言又止 不平 那些 難得 哪裡 不用 厭煩 中斷 聯繫 不會 忘記 什麼 關係 Boom BoomBoom 我們 Sha 風度翩翩 風情萬種 女人 GentlewomanI Gentlewoman 難道 Hey Dancing Oh 快樂 一舞 鍾情 sky my life 全世界 的話 太久 正要 不急不徐 你悶 前戲 漫長 爆點 太解 鎂光燈 怎麼 Bye 快快 喜歡 身邊 煩煩 現在 這個 上帝 十年 LaLaLa 極限 Lin yourself 念頭 綻放 快樂 再美 不過 擋不住 不要 my love 默契 愛到 求饒 打造 需要 互相 Cheer OH 你點 音樂 快樂 骨頭 感覺 IOH 立刻 孤獨 自轉 打烊 我心 Ma Baby Honey MaMa 給予 念頭 純真 投幣 值得 那個 因為 只為 自己 更好 脫掉 換上 選擇 離開 一個 終點 聽見 地平線 一邊 呼喚 多遠 乘著風 瘋狂 因為 那麼 靜靜地 撫摸 溫柔 臉龐 告訴 我天 盡頭 何模樣 一落 沒有 逃避 不如 哪個 療傷 溫暖 什麼 愛上你 這麼 負荷 別人 怎麼 喜歡 起來 現在 自己 勇敢 Right 音樂 搖擺 進來 終於 門外 闖進來 逃進來 諾言 發展 未來 留下來 停下來 隨心 所遇 隨性 讓你能 之間 發現 天空海闊 遇見 原來 從容不迫 飛翔 懂得 天空 迷航 有點 親愛 多虧 貼心 體諒 並非 Turning Running 在我心中 Know 有時候 永遠 Don Why Wanna Cry 百種 重點 號是 愛是 愛情 愛的 無法解釋 關鍵 造句 打卡 Baby 清醒 沒有 夢境 決定 愛情 何必 不能 無法 遠行 也許 總是 Don break my heart 溫柔 不願 獨自 喜悅 沒有 這裡 你給 勇氣 帶領 飛行 意義 MY LOVE OH 因為 喜歡 戀愛 魔力 不會 變得 加持 過來 關於 愛情 我愛你 值得 不會 沒有 最後 悲傷 衝動 盡頭 一場空 記得 選擇 我們 愛得 Lonely Still Crazy 喜怒哀愁 曾經 炙熱 愛火 愛或 不愛我 不要 一不愛 寧願 二不休 不必 曖昧 閃爍 對白 一無所有 擁有 坦誠 圓滿 劃過 墜落 從不 某個 承諾 過的 一瞬 之光 愛你 穿越時空 滲透 謝謝 願意 傾聽 時光 交換 眼裡 願意 千萬個 寫下 耳語 為名 守護 一顆 最後 化為 la Ooh 擁抱 大大的 yan 因為 我們 見面 沒有 天荒地老 擁抱 春雨 受了傷 能替 捨不得 光榮 再苦 還是 相擁 沒有 總要 說完 再見 以後 開始 愛多 NO 想念 今晚 尋找 若有情 無情 愛到 最後 分離 輪迴 印記 眉宇 獨影淚 不付 ll remember who 我會 相擁 看破 不用 逆轉 對錯 結果 這種 以後 不該 本來 總是 現在 怎麼 什麼 以前 寂寞 一個 萬歲 失戀 無罪 崩潰 眼淚 犯罪 孤獨 保證 醒來 平衡感 兩端 墜落 懸崖 遺憾 怎麼辦 勇敢 幸福 鋼索 夢想 人海中 交會 瞬間 邊界 月兒 彎彎 時間 彷彿 靜止 還未 如此 單身 在場 一個 同時 兩個 身體 什麼 分開 懷念 永遠 改變 不會 承諾 誠意 感動 天為 何愛卻 原點 習慣 什麼 你們 口氣 還是 一樣 溫暖 時間 總是 記得 當初 位置 還為 Oh 無法 改變 就算 保留 回憶 快沒了 聽見 only woman man 假設 願意 浪漫 依賴 寵愛 我們 承擔 忘不了 沒有 纏綿 永遠 醉人 誓言 一陣風 落恩恩 怨怨 也許 忘記 我們 眼淚 傻得 擁抱 曾經 那麼 那麼樣 驕傲 懷抱 還是 真的 雖然 不想 眼淚 會想 痛到 說放得 放開 沙啞 我們 愛情 更好 因為 已經 親愛 固執 會教人 成長 以為 請勿打擾 溫暖 因為 我們 並不 適合 這個 笑話 捨不得 太冷 體諒 我能 離開 感傷 那個 遠方 那麼 愛過 什麼 對方 幾個 記得 盡頭 妳是 生命 每個 強得 頭暈目眩 發抖 襲擊 不過 你給 傷口 再痛 傷痛 淚水 冷漠 背叛 一場 支離破碎 狂風 擁抱 我們 頑強 相愛 這是 溫暖 淚光 閃耀 驕傲 記得 沒有 說愛我 愛我 多久 是不是 輪廓 靈魂 一張 雙人 為何 我們 太長 難道 太短 思念 幸福 還以 當你 離開 我們 一點 抱緊 抱久 愛就會 多一點 時間 一條線 中間 不疲倦 啊啊啊 還有 什麼 一點 偶爾 還會 時候 一場 總會 一個 還有 寧願 回頭 風中 顫抖 因為 溫暖 足夠 大雨 不在乎 恰好 一班 巧合 沒有 路邊 餐廳 滿座 雨傘 帶多 時間 什麼 幾次 拿走 望著 覺得 沙發 上少 個人 曾經 那樣 背後 Love my matter how far 真相 嘶吼 命運 熱衷 終於 愛情 我們 這場 遊戲 五體投地 關於 佈下 承認 傷心 思念 曾經 何處 執著 籠罩 暖爐 原來 記憶 思緒 眉間 My love 什麼 偽裝 其實 沒有 卸下 風中 然後 放縱 寂寞 什麼 念舊 時間 難過 做夢 當你 膩了 以後 會來 從心 過去 不願 錯過 自欺 喧囂 曾經 那個 woo 答應 有時 現在 不斷 讓步 當成 殘酷 我要 愛他 那樣 義無反顧 最美 愛換個 季節 開花結果 時間 傷口 釀成 風雪 鏡頭 擁有 我們 一個 最後 嚐到 滿口 苦澀 特別感謝 結果 什麼 那個 愛的 越是 一個 體貼 背後 複雜 不夠 愛能 請原諒 時候 無路 可退 勇敢 那些 妥協 傷痕 對愛的 體貼 愛若 腐爛 約定 放棄 曾經 沒有 好消息 半滴 天荒地老 甚麼 東西 勾過 一個 理由 忘記 放棄 越想 抽離 最痛 距離 不在 身邊 沒有 開竅 回憶 打擾 不會 管不著 死掉 空空 大不了 擁抱 海角天涯 世間 萬物 相愛 雲與海 乘風破浪 時光 分開 難捱 終會 回頭 想著 oh 翻過 越過 好過 這份 什麼 愛我 解脫 只想 願意 寂寞 那裡 卻說 遙遠 已經 不夠 空間 尋找 愛就 該不該 打開 牽起來 變成 遺憾 趕快 趁現在 喜歡 身邊 愛與愁 我們 無法 活多久 還有 執著 這是 於是 燃燒 終於 愛歸 這是 愛你 因為 整個 美麗 沒理由 決定 無條件 軌跡 什麼 這麼 我累 假裝 無力 抉擇 曉得 哪裡 開始 不會 這樣 我們 好慢 眼到 美麗 謊話 想飛 時鐘 永遠 好長 尋找 張望 涼風 憂心 時刻 放過 不會 蕭瑟 擁抱 溫暖 Here 緊緊 每當 愛要 時候 總點 燈火 遼闊 總停 著愛吧 簡單 迷戀 愛的 拋向 滿足 天馬行空 變得 狂飆 緊張 一個 默默地 守護 愛情 欣賞 每個 緊張 面對 確定 回憶 關上 已經 時候 以為 快樂 回來 離開 難得 嘗試 在我心中 那時 湖聲靜 淚如櫻 怎麼 紛紛 傷心 短暫 約定 答應 瞬間 花開 因為 喜歡 戀愛 魔力 不會 變得 加持 過來 關於 愛情 光之海 點點 起來 沉沉 浮浮 這份 堅持 溫暖 胸懷 洗過 ma cu na lu 故鄉 回家 好動 小時候 成長 ei family Oh 守護 永遠 摧毀 Woo 我們 不會 改變 從來不 滿足 會想 有過 瘋狂 糊塗 膩了 傾訴 嫌棄 愛得 樸素 原來 練習 分手 傷口 變輕 海闊天空 殘留 一點 回頭 看怕 別人 怎麼 喜歡 起來 現在 自己 勇敢 Right 音樂 搖擺 Were More Like Me 拋開 現在 不合時宜 告別 真實 那些 陽光 也許 Shine 迎著 心灰 愛過 愛到 最後 淚水 懷疑 wo 沒有 盡頭 一直 什麼 走走 shine 更遠 界線 出遊 Hey 我們 覺得 多麼 渺小 轉念 有時候 低頭 彩紅 轉角 我們 拚命 鼻子走 當我 快樂 暫時 跳開 煩人 難過 傷心 再見 從前 一個 那個 快樂 夢想 逐夢 多虧 執著 摔過 Away Fly Just Run gonna 因為 溫暖 往前 發現 多美 快樂 簡單 踏著 遺失 發現 不過 轉個 念頭 瞬間 憂愁 面對 沒有 自我 失去 許多 考驗 人們 膽怯 兌現 曾經 一個 嘗試 旋轉 暈眩 帶來 遺憾 Ah 如何 茫然 勇敢 永遠 所有 這裡 離去 我們 悲傷 美麗 好想你 化作 陪伴 四季 孤單 多麼 走過 你給 當我 覺得 沮喪 堅強 無情 一種 悲傷 Oh 過往 遺忘 無法 分開 背對 ...

# %%
tags = jieba.analyse.extract_tags(all_tags_s, 50) #取Ｎ個tags
print(",".join(tags))
# Out:
# 我們,什麼,沒有,一個,愛情,怎麼,快樂,不會,因為,還是,永遠,感覺,時間,那麼,Oh,也許,一點,最後,擁抱,開始,這樣,愛的,時候,愛我,現在,離開,已經,一種,me,我要,回憶,眼淚,記得,未來,my,喜歡,love,發現,原來,無法,總是,以後,一樣,變成,終於,美麗,每個,曾經,oh,這是

# %% [markdown]
# ## 3. 文字雲呈現
# - WordCloud Module 功能
# - stopwords 停用字調整
# - 存檔

# %%
# 讀取欲透過文字雲計算詞頻的檔案
text = all_tags_s
# 建立停用字
stopwords = {}.fromkeys(["沒有","一個","什麼","那個"])  

wc = WordCloud(font_path="NotoSerifCJKtc-Black.otf", #設置字體
               background_color="white", #背景顏色
               max_words = 2000 , #文字雲顯示最大詞數
               stopwords=stopwords) #停用字詞

# 產生文字雲
wc.generate(text)

# 視覺化
plt.imshow(wc)
plt.axis("off")
plt.figure(figsize=(10,6), dpi = 100)
plt.show()

# 存檔
wc.to_file("lyrics/wordcloud1.jpg")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_123/1351272171.py in <module>
#      10
#      11 # 產生文字雲
# ---> 12 wc.generate(text)
#      13
#      14 # 視覺化
#
# ~/miniconda3/envs/tensorflow/lib/python3.7/site-packages/wordcloud/wordcloud.py in generate(self, text)
#     630         self
#     631         """
# --> 632         return self.generate_from_text(text)
#     633
#     634     def _check_generated(self):
#
# ~/miniconda3/envs/tensorflow/lib/python3.7/site-packages/wordcloud/wordcloud.py in generate_from_text(self, text)
#     612         """
#     613         words = self.process_text(text)
# --> 614         self.generate_from_frequencies(words)
#     615         return self
#     616
#
# ~/miniconda3/envs/tensorflow/lib/python3.7/site-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     445             else:
#     446                 self.generate_from_frequencies(dict(frequencies[:2]),
# --> 447                                                max_font_size=self.height)
#     448                 # find font sizes
#     449                 sizes = [x[1] for x in self.layout_]
#
# ~/miniconda3/envs/tensorflow/lib/python3.7/site-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     494             while True:
#     495                 # try to find a position
# --> 496                 font = ImageFont.truetype(self.font_path, font_size)
#     497                 # transpose font optionally
#     498                 transposed_font = ImageFont.TransposedFont(
#
# ~/miniconda3/envs/tensorflow/lib/python3.7/site-packages/PIL/ImageFont.py in truetype(font, size, index, encoding, layout_engine)
#     853
#     854     try:
# --> 855         return freetype(font)
#     856     except OSError:
#     857         if not isPath(font):
#
# ~/miniconda3/envs/tensorflow/lib/python3.7/site-packages/PIL/ImageFont.py in freetype(font)
#     850
#     851     def freetype(font):
# --> 852         return FreeTypeFont(font, size, index, encoding, layout_engine)
#     853
#     854     try:
#
# ~/miniconda3/envs/tensorflow/lib/python3.7/site-packages/PIL/ImageFont.py in __init__(self, font, size, index, encoding, layout_engine)
#     210                     return
#     211             self.font = core.getfont(
# --> 212                 font, size, index, encoding, layout_engine=layout_engine
#     213             )
#     214         else:
#
# OSError: cannot open resource

# %% [markdown]
# ## 討論：文字雲針對不同程度資料處理 part
# - 原歌詞檔案（未斷詞）
# - 原歌詞檔案（有斷詞）
# - 每首歌取前 10 大關鍵字（共 330 個）
# - 最終關鍵字（從上述 330 個挑 200 個）

# %%
#原歌詞檔案_未斷詞
text = open("lyrics/test1.txt").read()
stopwords = {}.fromkeys(["沒有","一個","什麼","那個"])  

wc = WordCloud(font_path="HYQiHei-25J.otf", #設置字體
               background_color="white", #背景顏色
               max_words = 2000 , #文字雲顯示最大詞數
               stopwords=stopwords) #停用字詞
wc.generate(text)
plt.imshow(wc)
plt.axis("off")
plt.figure(figsize=(10,6), dpi = 100)
plt.show()

# 存檔
wc.to_file("lyrics/wordcloud_test1.jpg")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-15-cbcaa9a1e469> in <module>
#       1 #原歌詞檔案_未斷詞
# ----> 2 text = open("lyrics/test1.txt").read()
#       3 stopwords = {}.fromkeys(["沒有","一個","什麼","那個"])
#       4
#       5 wc = WordCloud(font_path="HYQiHei-25J.otf", #設置字體
#
# UnicodeDecodeError: 'cp950' codec can't decode byte 0xe6 in position 0: illegal multibyte sequence

# %%
#已斷詞
text = open("lyrics/lyrics_cut_mayday.dataset", encoding = "utf-8").read()
stopwords = {}.fromkeys(["沒有","一個","什麼","那個"])  

wc = WordCloud(font_path="DroidSansMono.otf", #設置字體
               background_color="white", #背景顏色
               max_words = 2000 , #文字雲顯示最大詞數
               stopwords=stopwords) #停用字詞
wc.generate(text)
plt.imshow(wc)
plt.axis("off")
plt.figure(figsize=(10,6), dpi = 100)
#plt.imshow(alice_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.show()

# save
wc.to_file("lyrics/wordcloud_test2.jpg")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-12-0de70e371c79> in <module>
#       7                max_words = 2000 , #文字雲顯示最大詞數
#       8                stopwords=stopwords) #停用字詞
# ----> 9 wc.generate(text)
#      10 plt.imshow(wc)
#      11 plt.axis("off")
#
# C:\ProgramData\Anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate(self, text)
#     630         self
#     631         """
# --> 632         return self.generate_from_text(text)
#     633
#     634     def _check_generated(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate_from_text(self, text)
#     612         """
#     613         words = self.process_text(text)
# --> 614         self.generate_from_frequencies(words)
#     615         return self
#     616
#
# C:\ProgramData\Anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     445             else:
#     446                 self.generate_from_frequencies(dict(frequencies[:2]),
# --> 447                                                max_font_size=self.height)
#     448                 # find font sizes
#     449                 sizes = [x[1] for x in self.layout_]
#
# C:\ProgramData\Anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     494             while True:
#     495                 # try to find a position
# --> 496                 font = ImageFont.truetype(self.font_path, font_size)
#     497                 # transpose font optionally
#     498                 transposed_font = ImageFont.TransposedFont(
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\ImageFont.py in truetype(font, size, index, encoding, layout_engine)
#     640
#     641     try:
# --> 642         return freetype(font)
#     643     except OSError:
#     644         if not isPath(font):
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\ImageFont.py in freetype(font)
#     637
#     638     def freetype(font):
# --> 639         return FreeTypeFont(font, size, index, encoding, layout_engine)
#     640
#     641     try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\ImageFont.py in __init__(self, font, size, index, encoding, layout_engine)
#     186                     return
#     187             self.font = core.getfont(
# --> 188                 font, size, index, encoding, layout_engine=layout_engine
#     189             )
#     190         else:
#
# OSError: cannot open resource

# %%
# 把所有歌的10大tags取tags，也就是從330個tags (33*10) 精煉成取100個tags
wtags_all = codecs.open("lyrics/lyrics_tags_combine.txt", "w", "utf-8")
with open("lyrics/lyrics_tags.txt", "rb") as f3:
    for line in f3:
        tags = jieba.analyse.extract_tags(line,200)
        wtags_all.write(" ".join(tags))
f3.close()

# %%
#最終關鍵字
text = open("lyrics/lyrics_tags_combine.txt").read()
stopwords = {}.fromkeys(["沒有","一個","什麼","那個"])  

wc = WordCloud(font_path="NotoSerifCJKtc-Black.otf", #設置字體
               background_color="white", #背景顏色
               max_words = 2000 , #文字雲顯示最大詞數
               stopwords=stopwords) #停用字詞
wc.generate(text)
plt.imshow(wc)
plt.axis("off")
plt.figure(figsize=(10,6), dpi = 100)
#plt.imshow(alice_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.show()

# save
wc.to_file("lyrics/wordcloud_test4.jpg")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-93cda079b27d> in <module>
#       7                max_words = 2000 , #文字雲顯示最大詞數
#       8                stopwords=stopwords) #停用字詞
# ----> 9 wc.generate(text)
#      10 plt.imshow(wc)
#      11 plt.axis("off")
#
# C:\ProgramData\Anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate(self, text)
#     630         self
#     631         """
# --> 632         return self.generate_from_text(text)
#     633
#     634     def _check_generated(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate_from_text(self, text)
#     612         """
#     613         words = self.process_text(text)
# --> 614         self.generate_from_frequencies(words)
#     615         return self
#     616
#
# C:\ProgramData\Anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     402         if len(frequencies) <= 0:
#     403             raise ValueError("We need at least 1 word to plot a word cloud, "
# --> 404                              "got %d." % len(frequencies))
#     405         frequencies = frequencies[:self.max_words]
#     406
#
# ValueError: We need at least 1 word to plot a word cloud, got 0.
